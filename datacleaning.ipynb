# %%
# !pip install langdetect  
from langdetect import detect
import pandas as pd

# %%
df_review=pd.read_csv("/Users/yingzhaozhou/reviews.csv")

df_review.dropna()
# Out:
#         listing_id         id        date  reviewer_id reviewer_name  \
# 0             3781   37776825  2015-07-10     36059247          Greg
# 1             3781   41842494  2015-08-09     10459388           Tai
# 2             3781   45282151  2015-09-01     12264652        Damien
# 3             3781   49022647  2015-09-30     41426327          Mike
# 4             3781   52503327  2015-10-30     15151513          Ivan
# 5             3781   63371931  2016-02-22     55456499     John-Mark
# 6             3781   67909504  2016-04-01     55456499     John-Mark
# 7             3781   97906006  2016-08-28     88528884         Elisa
# 8             3781  105143774  2016-09-30      1342806        Nicole
# 9             3781  129692749  2017-02-01     55126634        Carlos
# 10            3781  155725362  2017-05-28    117390053       Carolyn
# 11            3781  184356065  2017-08-19     70187382        Justin
# 12            3781  194026175  2017-09-15     11888800          John
# ...

# %%
def trans(text):
    textresult=type(text).__name__
    return(textresult)

# %%
df_review["type"]=df_review.comments.apply(trans)

# %%
df_review
df_review=df_review[df_review["type"]=="str"]
df_review
# Out:
#         listing_id         id        date  reviewer_id reviewer_name  \
# 0             3781   37776825  2015-07-10     36059247          Greg
# 1             3781   41842494  2015-08-09     10459388           Tai
# 2             3781   45282151  2015-09-01     12264652        Damien
# 3             3781   49022647  2015-09-30     41426327          Mike
# 4             3781   52503327  2015-10-30     15151513          Ivan
# 5             3781   63371931  2016-02-22     55456499     John-Mark
# 6             3781   67909504  2016-04-01     55456499     John-Mark
# 7             3781   97906006  2016-08-28     88528884         Elisa
# 8             3781  105143774  2016-09-30      1342806        Nicole
# 9             3781  129692749  2017-02-01     55126634        Carlos
# 10            3781  155725362  2017-05-28    117390053       Carolyn
# 11            3781  184356065  2017-08-19     70187382        Justin
# 12            3781  194026175  2017-09-15     11888800          John
# ...

# %%
df_review["len"]=df_review.comments.apply(len)
df_review=df_review[df_review['len']>10]
df_review
# Out:
#         listing_id         id        date  reviewer_id reviewer_name  \
# 0             3781   37776825  2015-07-10     36059247          Greg
# 1             3781   41842494  2015-08-09     10459388           Tai
# 2             3781   45282151  2015-09-01     12264652        Damien
# 3             3781   49022647  2015-09-30     41426327          Mike
# 4             3781   52503327  2015-10-30     15151513          Ivan
# 5             3781   63371931  2016-02-22     55456499     John-Mark
# 6             3781   67909504  2016-04-01     55456499     John-Mark
# 7             3781   97906006  2016-08-28     88528884         Elisa
# 8             3781  105143774  2016-09-30      1342806        Nicole
# 9             3781  129692749  2017-02-01     55126634        Carlos
# 10            3781  155725362  2017-05-28    117390053       Carolyn
# 11            3781  184356065  2017-08-19     70187382        Justin
# 12            3781  194026175  2017-09-15     11888800          John
# ...

# %%
df_review[["listing_id","comments"]]
df_review["detect"]=df_review.comments.apply(detect)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_review=df_review[df_review["detect"]=="en"]
df_review
# Out:
#         listing_id         id        date  reviewer_id reviewer_name  \
# 0             3781   37776825  2015-07-10     36059247          Greg
# 1             3781   41842494  2015-08-09     10459388           Tai
# 2             3781   45282151  2015-09-01     12264652        Damien
# 3             3781   49022647  2015-09-30     41426327          Mike
# 4             3781   52503327  2015-10-30     15151513          Ivan
# 5             3781   63371931  2016-02-22     55456499     John-Mark
# 6             3781   67909504  2016-04-01     55456499     John-Mark
# 7             3781   97906006  2016-08-28     88528884         Elisa
# 8             3781  105143774  2016-09-30      1342806        Nicole
# 9             3781  129692749  2017-02-01     55126634        Carlos
# 10            3781  155725362  2017-05-28    117390053       Carolyn
# 11            3781  184356065  2017-08-19     70187382        Justin
# 12            3781  194026175  2017-09-15     11888800          John
# ...

# %%
df_review.to_csv("review_complete.csv")

# %%
# !pip install googletrans
from googletrans import Translator
#from translate import Translator
import pandas as pd

translator = Translator()
words=["Bonjour","Beau temps"]
word=pd.DataFrame(words,columns=["name"])
word

# #print(translator.translate("Bonjour").text)
word["trans"]=word.name.apply(translator.translate).apply(getattr, args=('text',))
word
# from py_translator import Translator
# s = Translator().translate(text='Hello my friend', dest='es').text
# print(s)
# Out:
# ...
#          name         trans
# 0     Bonjour         Hello
# 1  Beau temps  Good weather

# %%
df_review=pd.read_csv("/Users/yingzhaozhou/reviews.csv")
df_review=df_review.iloc[500:1000]
df_review = df_review[["listing_id","comments"]]
df_review["trans"] = df_review['comments'].apply(translator.translate).apply(getattr, args=('text',))

# %%
df_review
# Out:
#      listing_id                                           comments  \
# 500       29765  Elizabeth is an amazing host and i highly reco...
# 501       29765  We recently stayed at Elizabeth's Moroccan Fur...
# 502       29765  Elizabeth was an excellent host and we loved s...
# 503       29765  Beautiful place and perfectly located.  Elizab...
# 504       29765  Elizabeth provide an amazing place to stay tha...
# 505       29765  Elizabeth is the most amazing host. We arrived...
# 506       29765  My boyfriend and I stayed at the Moroccan luxu...
# 507       29765  It was Amazing!! I took my girlfriend here for...
# 508       29765  This room is amazing! It was such a relaxing a...
# 509       29765      We could not be more pleased with our stay...
# 510       29765  Gorgeous interior; I love the colour & plush f...
# 511       29765  My fiancé and I stayed here one night back in ...
# 512       29765  This place is a beautiful house built in the 1...
# ...
